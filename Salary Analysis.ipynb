# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from wordcloud import WordCloud
import seaborn as sns

# %%
df=pd.read_csv(r'developer_survey_2020\survey_results_public.csv')

# %%
df.head(5)
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1                     I am a developer by profession      Yes
# 1           2                     I am a developer by profession       No
# 2           3                        I code primarily as a hobby      Yes
# 3           4                     I am a developer by profession      Yes
# 4           5  I used to be a developer by profession, but no...      Yes
#
#     Age Age1stCode CompFreq  CompTotal  ConvertedComp             Country  \
# 0   NaN         13  Monthly        NaN            NaN             Germany
# 1   NaN         19      NaN        NaN            NaN      United Kingdom
# 2   NaN         15      NaN        NaN            NaN  Russian Federation
# 3  25.0         18      NaN        NaN            NaN             Albania
# 4  31.0         16      NaN        NaN            NaN       United States
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 64461 entries, 0 to 64460
# Data columns (total 61 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Respondent                    64461 non-null  int64
#  1   MainBranch                    64162 non-null  object
#  2   Hobbyist                      64416 non-null  object
#  3   Age                           45446 non-null  float64
#  4   Age1stCode                    57900 non-null  object
#  5   CompFreq                      40069 non-null  object
#  6   CompTotal                     34826 non-null  float64
#  7   ConvertedComp                 34756 non-null  float64
#  8   Country                       64072 non-null  object
#  9   CurrencyDesc                  45472 non-null  object
#  10  CurrencySymbol                45472 non-null  object
#  11  DatabaseDesireNextYear        44070 non-null  object
# ...

# %%
df.shape
# Out:
# (64461, 61)

# %%
Average_salary_df=df.copy()

# %%
#dropping missing values
Average_salary_df.dropna(subset=['Country'],inplace=True)

# %%
#From which country most of our respondents are from
from wordcloud import WordCloud
def wordcloud(data):
    plt.figure(figsize = (25,15))
    wordcloud = WordCloud(
    background_color = 'white',
        collocations=False,
             width = 1920,
             height = 1080
             ).generate(" ".join(data))
    wordcloud.to_file(r'J:\Carrer Growth\UDACITY\Project\N.png')
    plt.imshow(wordcloud)
    plt.axis('off')
    plt.show()
    return wordcloud

wordcloud(Average_salary_df.Country);

# %% [markdown]
# According to many articles, Russia belongs to Asia. However, the vast majority of its population lives in Europe, so it is being considered a European region. There are some confusions with Transcontinental Countries like Cyprus.Countries are classified into regions based on their geographical location excluding Russia.
# Reference https://www.nationsonline.org/oneworld/asia.htm

# %%
#Asian Regions : Conventionally there are six main geographical regions or subregions in Asia.Northern Asia,Western Asia,Central Asia,Eastern Asia,Southern Asia,Southeast Asia.

Western_Asia=["Armenia","Azerbaijan","Bahrain","Cyprus","Georgia","Iran","Iraq","Israel",
              "Jordan","Kuwait","Lebanon","Oman","Qatar","Saudi Arabia","State of Palestine",
              "Syria","Turkey","United Arab Emirates","Yemen"]


Central_Asia=["Afghanistan","Kazakhstan","Kyrgyzstan","Tajikistan","Turkmenistan","Uzbekistan"]


#EastAsia  : Republic of Korea is selected by few of the respondents,so adding that too separatetly
East_Asia=["China","Hong Kong","Macao SAR","Japan","South Korea","North Korea","Republic of Korea",
           "Mongolia","Taiwan"]


South_Asia=["Bangladesh","Bhutan","India","Maldives","Nepal","Pakistan","Sri Lanka"]


Southeast_Asia=["Brunei Darussalam","Cambodia","Indonesia","Lao PDR","Malaysia","Myanmar","Burma",
                "Philippines","Singapore","Kuwait","Lebanon","Thailand","Timor-Leste","Vietnam"]



#European Regions : there are four main geographical regions or subregions in Europ.Northern Europe,Western Europe,Eastern Europe,Southern Europe
    
Northern_Europe=["Denmark","Estonia","Faroe Islands","Finland","Greenland","Iceland","Ireland","Latvia",
                 "Lithuania","Northern Ireland","Norway","Scotland","Sweden","United Kingdom","Birmingham","Wales"]


Western_Europe=["Austria","Belgium","France","Germany","Liechtenstein","Luxembourg","Netherlands","Switzerland"]

Eastern_Europe=["Bulgaria","Czechia","Belarus","Hungary","Poland","Romania","Slovakia","Ukraine","Russian Federation","Russia"]

Southern_Europe=["Albania","Andorra","Bosnia and Herzegovina","Croatia","Gibraltar","Greece","Italy","Kosovo",
                 "North Macedonia","Malta","Monaco","Montenegro","Portugal","San Marino","Serbia","Slovenia",
                 "Spain","Vatican City State"]





#America :There are four main geographical regions or subregions in the Americas.North America,The Caribbean,Central America and South America

North_America_region=["Canada","Andorra","Greenland","Mexico","United States"]

Caribbean=["Anguilla","Antigua and Barbuda","Aruba","Bahamas","Barbados","Bermuda","British Virgin Islands",
           "Ukraine","Cayman Islands","Cuba","Curaçao ","Dominica","Dominican Republic","Grenada",
           "Guadeloupe", "Haiti","Jamaica","Martinique","Montserrat","Puerto Rico ","Saint Kitts and Nevis",
           "Saint Lucia","Saint Vincent and the Grenadines","Trinidad and Tobago","US Virgin Islands"]


Central_America=["Belize","Costa Rica","El Salvador","Guatemala","Honduras","Nicaragua","Panama"]

South_America=["Argentina","Bolivia","Brazil","Chile","Colombia","Ecuador","French Guiana","Guyana","Paraguay",
               "Peru","Suriname","Uruguay","Venezuela"]



#African Regions : There are five main geographical regions or subregions in Africa.North Africa,West Africa,Central Africa,East Africa,Southern Africa
    
    
North_Africa=["Algeria","Egypt","Libya","Morocco","Sudan","Tunisia","Western Sahara"]

West_Africa=["Benin","Bolivia","Burkina Faso","Cape Verde","Côte dIvoire","Gambia","Ghana","Guinea",
             "Guinea-Bissau","Liberia","Mali","Mauritania","Niger","Nigeria","Saint Helena","Senegal",
             "Sierra Leone","Togo"]
    
Central_Africa=["Angola","Cameroon","Central African Republic","Chad","Congo","Equatorial Guinea","Gabon",
                "São Tomé & Príncipe"]

East_Africa=["Burundi","Comoros","Djibouti","Eritrea","Ethiopia","Kenya","Madagascar","Malawi","Mauritius",
             "Mozambique","Réunion","Rwanda","Seychelles","Somalia and Somaliland","South Sudan","Tanzania",
             "Uganda","Zambia","Zimbabwe"]

Southern_Africa=["Botswana","Lesotho","Namibia","South Africa","Swaziland"]
  
    
#Oceania:There are four main geographical regions Oceania.Australia/New Zealand,Melanesia,Micronesia,Polynesia



Australia_New_Zealand=["Australia","New Zealand"]

Melanesia=["Fiji","New Caledonia","Papua New Guinea","Solomon Islands","Vanuatu"]
    
Micronesia=["Guam","Kiribati","Marshall Islands","Micronesia","Nauru","Northern Mariana Islands","Palau"]

Polynesia=["American Samoa","Cook Islands","Easter Island","French Polynesia","Hawaii","Pitcairn","Samoa",
           "Tonga","Tuvalu"]

# %%
#Continents
Asia=["Northern Asia","Western Asia","Central Asia","East Asia","South Asia","Southeast Asia"]

Europe=["Northern Europe","Western Europe","Eastern Europe","Southern Europe"]

North_America_continent=["North America","Caribbean","Central America"]

Africa=["North Africa","West Africa","Central Africa","East Africa","Southern Africa"]

Australia=["Australia/New Zealand","Melanesia","Micronesia","Polynesia"]

# %%
#function to create region name from country
def combine(countryname):
    #Asian Regions : There are six main geographical regions or subregions in Asia.Northern Asia,Western Asia,
    #Central Asia,Eastern Asia,Southern Asia,Southeast Asia.

   #Western_Asia
    if countryname in Western_Asia:
        return 'Western Asia'
    
    #Central Asia
    elif countryname in Central_Asia:
         return 'Central Asia'
        
     #East Asia  : Republic of Korea is selected by few of the respondents,so adding that too separatetly 
    elif countryname in East_Asia:
        return 'East Asia'
    
    #South Asia
    elif countryname in South_Asia:
        return 'South Asia'
    
    #Southeast Asia
    elif countryname in Southeast_Asia:
        return 'Southeast Asia'
    
    #European Regions : there are four main geographical regions or subregions in Europ.Northern Europe,Western Europe,Eastern Europe,Southern Europe
    #Northern Europe
    elif countryname in Northern_Europe:
        return 'Northern Europe'
    
    #Western Europe
    elif countryname in Western_Europe:
        return 'Western Europe'

    #Eastern Europe
    elif countryname in Eastern_Europe:
        return 'Eastern Europe'
    
    #Southern Europe
    elif countryname in Southern_Europe:
        return 'Southern Europe'
    
    #America :There are four main geographical regions or subregions in the Americas.North America,The Caribbean,Central America and South America
    #North America
    elif countryname in North_America_region:
        return 'North America'
        
    
    #Caribbean
    elif countryname in Caribbean:
        return 'Caribbean'
    
    #Central America 
    elif countryname in Central_America:
        return 'Central America'
    
    #South America
    elif countryname in South_America:
        return 'South America'
    
    
    #African Regions : There are five main geographical regions or subregions in Africa.North Africa,West Africa,Central Africa,East Africa,Southern Africa
    #North Africa
    elif countryname in North_Africa:
        
        return 'North Africa'
    
    #West Africa 
    elif countryname in West_Africa:
        return 'West Africa'
    
    #Central Africa 
    elif countryname in Central_Africa:
        return 'Central Africa'
    
    #East Africa
    elif countryname in East_Africa:
        return 'East Africa'
    
    #Southern Africa
    elif countryname in Southern_Africa:
        return 'Southern Africa'
    
   
    #Oceania:There are four main geographical regions Oceania.Australia/New Zealand,Melanesia,Micronesia,Polynesia
    #Australia/New Zealand
    elif countryname in Australia_New_Zealand:
        return 'Australia/New Zealand'
   
    #Melanesia
    elif countryname in Melanesia:
        return 'Melanesia'
    #Micronesia
    elif countryname in Micronesia:
        return 'Micronesia'
    #Polynesia
    elif countryname in Polynesia:
        return 'Polynesia'

# %%
def continents(countryname):
    if (countryname in Northern_Europe or countryname in Western_Europe or countryname in Eastern_Europe or countryname in Southern_Europe):
        
        return 'Europe'
    
    elif(countryname in Western_Asia or countryname in Central_Asia or countryname in East_Asia or countryname in South_Asia or countryname in Southeast_Asia):
        return 'Asia'
    

    elif(countryname in North_America_region or countryname in Caribbean or countryname in Central_America):
        return 'North America'
  
    elif countryname in South_America:
        return 'South America'
    
    elif(countryname in North_Africa or countryname in West_Africa or countryname in Central_Africa or countryname in East_Africa or countryname in Southern_Africa):
        return 'Africa'
        
    elif(countryname in Australia_New_Zealand or countryname in Melanesia or countryname in Micronesia or countryname in Polynesia):
        return 'Australia'

# %% [markdown]
# # 1)What is the average salary for IT professionals in different Regions?

# %%
#dropping missing values
Average_salary_df.dropna(subset=['ConvertedComp'],inplace=True)

# %%
#creating Continent Column based on the country
Average_salary_df['Continent'] = Average_salary_df["Country"].apply(continents)

# %%
Average_salary_df['Continent'].value_counts()
# Out:
# Europe           14695
# North America    10019
# Asia              5750
# South America     1856
# Australia          976
# Africa             870
# Name: Continent, dtype: int64

# %%
plt.figure(figsize = (9.2, 12))
g=sns.barplot(x='Continent',y='ConvertedComp',data=Average_salary_df,ci=None)
g.yaxis.set_ticks([25000,50000,75000,100000,125000,150000,175000,200000])
g.axes.set_title("Average Salary for each Continent",fontsize=20)
g.set_xlabel("Continents",fontsize=18)
g.set_ylabel("Salary",fontsize=18)
# Out:
# Text(0, 0.5, 'Salary')

# %% [markdown]
# ##### North America is leading the chart by a lot.

# %%
#Creating region name based on the country
Average_salary_df['Region'] = Average_salary_df["Country"].apply(combine)

# %%
Average_salary_df['Region'].value_counts()
# Out:
# North America            9811
# Western Europe           5201
# Northern Europe          4524
# South Asia               3381
# Eastern Europe           2623
# Southern Europe          2347
# South America            1856
# Western Asia             1265
# Australia/New Zealand     975
# Southeast Asia            549
# East Asia                 471
# Southern Africa           308
# West Africa               220
# North Africa              175
# East Africa               155
# Central America           125
# Central Asia               84
# Caribbean                  83
# Central Africa             12
# Melanesia                   1
# Name: Region, dtype: int64

# %%
x = Average_salary_df[Average_salary_df['Continent']=='Africa']['Region']
plt.figure(figsize = (3, 5))
g=sns.barplot(x=x,y='ConvertedComp',data=Average_salary_df,ci=None)
g.yaxis.set_ticks([25000,50000,75000,100000,125000,150000,175000,200000])
g.set_xticklabels(g.get_xticklabels(), rotation=90)

g.set(xlabel='Africa', ylabel='Salary')
# Out:
# [Text(0.5, 0, 'Africa'), Text(0, 0.5, 'Salary')]

# %%
x = Average_salary_df[Average_salary_df['Continent']=='Asia']['Region']
plt.figure(figsize = (3, 5))
g=sns.barplot(x=x,y='ConvertedComp',data=Average_salary_df,ci=None)
g.yaxis.set_ticks([25000,50000,75000,100000,125000,150000,175000,200000])
g.set_xticklabels(g.get_xticklabels(), rotation=90)
g.set(xlabel='Asia', ylabel='Salary')
# Out:
# [Text(0.5, 0, 'Asia'), Text(0, 0.5, 'Salary')]

# %%
x = Average_salary_df[Average_salary_df['Continent']=='Europe']['Region']
plt.figure(figsize = (3, 5))
g=sns.barplot(x=x,y='ConvertedComp',data=Average_salary_df,ci=None)
g.yaxis.set_ticks([25000,50000,75000,100000,125000,150000,175000,200000])
g.set_xticklabels(g.get_xticklabels(), rotation=90)
g.set(xlabel='Europe', ylabel='Salary')
# Out:
# [Text(0.5, 0, 'Europe'), Text(0, 0.5, 'Salary')]

# %%
x = Average_salary_df[Average_salary_df['Continent']=='North America']['Region']
plt.figure(figsize = (3, 5))
g=sns.barplot(x=x,y='ConvertedComp',data=Average_salary_df,ci=None)
g.yaxis.set_ticks([25000,50000,75000,100000,125000,150000,175000,200000])
g.set_xticklabels(g.get_xticklabels(), rotation=90)
g.set(xlabel='North America', ylabel='Salary')
# Out:
# [Text(0.5, 0, 'North America'), Text(0, 0.5, 'Salary')]

# %%
x = Average_salary_df[Average_salary_df['Continent']=='Australia']['Region']
plt.figure(figsize = (3, 5))
g=sns.barplot(x=x,y='ConvertedComp',data=Average_salary_df,ci=None)
g.yaxis.set_ticks([25000,50000,75000,100000,125000,150000,175000,200000])
g.set_xticklabels(g.get_xticklabels(), rotation=0)
g.set(xlabel='Australia', ylabel='Salary')
# Out:
# [Text(0.5, 0, 'Australia'), Text(0, 0.5, 'Salary')]

# %%
x = Average_salary_df[Average_salary_df['Continent']=='South America']['Region']
plt.figure(figsize = (3, 5))

g=sns.barplot(x=x,y='ConvertedComp',data=Average_salary_df,ci=None)
g.yaxis.set_ticks([25000,50000,75000,100000,125000,150000,175000,200000])
g.set_xticklabels(g.get_xticklabels(), rotation=0)
g.set(xlabel='South America', ylabel='Salary')
# Out:
# [Text(0.5, 0, 'South America'), Text(0, 0.5, 'Salary')]

# %% [markdown]
# # 2) Will a Professional degree or Master’s degree help me to get a good salary?

# %%
Education_df=df.copy()

# %%
#removing missing data
Education_df.dropna(subset=['EdLevel','ConvertedComp'],inplace=True)

# %%
#what are the different education level's from the dataset?
Education_df['EdLevel'].value_counts()
# Out:
# Bachelor’s degree (B.A., B.S., B.Eng., etc.)                                          16874
# Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                                        8668
# Some college/university study without earning a degree                                 4086
# Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)     1466
# Associate degree (A.A., A.S., etc.)                                                    1168
# Other doctoral degree (Ph.D., Ed.D., etc.)                                             1142
# Professional degree (JD, MD, etc.)                                                      477
# I never completed any formal education                                                  154
# Primary/elementary school                                                               153
# Name: EdLevel, dtype: int64

# %%
#Considering only Professional degree,Master’s degree and doctoral degree's are higher formal education
def education(degree):
    if degree in ("Professional degree (JD, MD, etc.)","Other doctoral degree (Ph.D., Ed.D., etc.)","Master’s degree (M.A., M.S., M.Eng., MBA, etc.)"):
        return 1
    else:
        return 0

# %%
#creating region column
Education_df['Region']=Education_df['Country'].apply(combine)

# %%
#Combining  education levels to create higher formal education column
Education_df['HigherEd']=Education_df['EdLevel'].apply(education)
Education_df['HigherEd'].mean()
# Out:
# 0.3008950508950509

# %%
#creating two different dataframes
education_1=Education_df[Education_df['HigherEd']==1]
education_0=Education_df[Education_df['HigherEd']==0]

# %%
education_0.head(3)
# Out:
#     Respondent                      MainBranch Hobbyist   Age Age1stCode  \
# 7            8  I am a developer by profession      Yes  36.0         12
# 10          11  I am a developer by profession      Yes  23.0         13
# 11          12  I am a developer by profession       No  49.0         42
#
#    CompFreq  CompTotal  ConvertedComp         Country          CurrencyDesc  \
# 7    Yearly   116000.0       116000.0   United States  United States dollar
# 10   Yearly    31000.0        40070.0  United Kingdom        Pound sterling
# 11  Monthly     1100.0        14268.0           Spain         European Euro
#
#     ... Trans                                     UndergradMajor  \
# 7   ...    No  Computer science, computer engineering, or sof...
# 10  ...    No  Computer science, computer engineering, or sof...
# 11  ...    No                          Mathematics or statistics
#
#      WebframeDesireNextYear                  WebframeWorkedWith  \
# ...

# %%
education_1.head(3)
# Out:
#     Respondent                      MainBranch Hobbyist   Age Age1stCode  \
# 9           10  I am a developer by profession      Yes  22.0         14
# 23          24  I am a developer by profession      Yes  45.0         14
# 40          41  I am a developer by profession       No   NaN         15
#
#    CompFreq  CompTotal  ConvertedComp         Country          CurrencyDesc  \
# 9    Yearly    25000.0        32315.0  United Kingdom        Pound sterling
# 23   Yearly    85000.0        91883.0         Germany         European Euro
# 40   Yearly   106000.0       106000.0   United States  United States dollar
#
#     ... Trans                                     UndergradMajor  \
# 9   ...    No                          Mathematics or statistics
# 23  ...    No  Another engineering discipline (such as civil,...
# 40  ...   NaN  Computer science, computer engineering, or sof...
#
#    WebframeDesireNextYear WebframeWorkedWith  \
# 9            Flask;jQuery       Flask;jQuery
# ...

# %%
#Pie Graph
labels = ["Max of Bachelors Higher Ed","Higher Formal Education"]
size = Education_df['HigherEd'].value_counts()
plt.rcParams['figure.figsize'] = (7, 5)
explode = (0, 0.1) 
g=plt.pie(size, labels=labels,explode=explode, autopct= '%1.1f%%', shadow = True, startangle = 90)
plt.title('Formal Education Distribution', fontsize = 20)
# Out:
# Text(0.5, 1.0, 'Formal Education Distribution')

# %% [markdown]
# ##### 30.1% of our respondents have higher formal education

# %%
#combining higher education with regions
Region_education_0=education_0.groupby('Region')['ConvertedComp'].mean().reset_index()
Region_education_1=education_1.groupby('Region')['ConvertedComp'].mean().reset_index()

# %%
#creating difference in earnings bar plot
from matplotlib.pyplot import *

Region_education_combined=Region_education_1.merge(Region_education_0,left_on="Region",right_on="Region",how="outer")

Region_education_combined.columns=["Region","Higher Formal Education Earnings($)","Max of Bachelors Higher Ed Earnings($)"]
Region_education_combined["Higher Formal Education Earnings($)"].fillna(0, inplace=True)


Region_education_combined['Difference in Earnings($)'] = Region_education_combined['Higher Formal Education Earnings($)'] - Region_education_combined['Max of Bachelors Higher Ed Earnings($)']

Region_education_combined.style.bar(subset=['Difference in Earnings($)'], align='mid', color=['#d65f5f', '#5fba7d'])
# Out:
# <style  type="text/css" >
# #T_5bb17_row0_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg,#d65f5f 25.3%, transparent 25.3%);
#         }#T_5bb17_row1_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 25.3%, #5fba7d 25.3%, #5fba7d 47.1%, transparent 47.1%);
#         }#T_5bb17_row2_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 25.3%, #5fba7d 25.3%, #5fba7d 27.0%, transparent 27.0%);
#         }#T_5bb17_row3_col3{
#             width:  10em;
#              height:  80%;
#             background:  linear-gradient(90deg, transparent 9.6%, #d65f5f 9.6%, #d65f5f 25.3%, transparent 25.3%);
#         }#T_5bb17_row4_col3{
#             width:  10em;
#              height:  80%;
# ...

# %% [markdown]
# # 3) How is the average salary varied in a Small sized organizations and Established Big Companies in different regions?

# %%
org_df=df.copy()

# %%
#EDA
org_df['OrgSize'].value_counts()
# Out:
# 20 to 99 employees                                    9597
# 100 to 499 employees                                  8311
# 10,000 or more employees                              6149
# 1,000 to 4,999 employees                              4863
# 2 to 9 employees                                      4409
# 10 to 19 employees                                    4127
# 500 to 999 employees                                  2880
# Just me - I am a freelancer, sole proprietor, etc.    2190
# 5,000 to 9,999 employees                              1808
# Name: OrgSize, dtype: int64

# %%
#dropping missing values
org_df.dropna(subset=['OrgSize','Employment','ConvertedComp'],inplace=True)

# %%
def orgsize(size):
    if size in ("2 to 9 employees","10 to 19 employees","20 to 99 employees"):
        return 'Small'
    elif size in ("100 to 499 employees","500 to 999 employees"):
        return 'Medium'
    elif size in ("1,000 to 4,999 employees","5,000 to 9,999 employees","10,000 or more employee"):
        return 'Large'

# %%
#considering only respondents who are employed currently
org_df=org_df[org_df['Employment']=='Employed full-time']

# %%
org_df['Org_size']=org_df['OrgSize'].apply(orgsize)

# %%
org_df['Org_size'].value_counts()
# Out:
# Small     12064
# Medium     8399
# Large      5015
# Name: Org_size, dtype: int64

# %%
#creating Region and Continent column based on country
org_df['Region']=org_df['Country'].apply(combine)
org_df['Continent']=org_df['Country'].apply(continents)

# %%
x = org_df[org_df['Continent']=='Asia']['Region']
plt.figure(figsize = (7, 5))
g=sns.barplot(x=x,y='ConvertedComp',data=org_df,ci=None,hue='Org_size')
g.yaxis.set_ticks([25000,50000,75000,100000,125000,150000,175000,200000])

g.set(xlabel='Asia', ylabel='Salary')
g.legend(title='Organization Size',loc='upper right')

# %%
x = org_df[org_df['Continent']=='Australia']['Region']
plt.figure(figsize = (7, 5))
g=sns.barplot(x=x,y='ConvertedComp',data=org_df,ci=None,hue='Org_size')
g.yaxis.set_ticks([25000,50000,75000,100000,125000,150000,175000,200000])
g.set(xlabel='Australia', ylabel='Salary')
g.legend(title='Organization Size',loc='upper right')

# %%
x = org_df[org_df['Continent']=='Africa']['Region']
plt.figure(figsize = (7, 5))
g=sns.barplot(x=x,y='ConvertedComp',data=org_df,ci=None,hue='Org_size')
g.yaxis.set_ticks([25000,50000,75000,100000,125000,150000,175000,200000])
g.set(xlabel='Africa', ylabel='Salary')
g.legend(title='Organization Size',loc='upper right')

# %%
x = org_df[org_df['Continent']=='North America']['Region']
plt.figure(figsize = (7, 5))
g=sns.barplot(x=x,y='ConvertedComp',data=org_df,ci=None,hue='Org_size')
g.yaxis.set_ticks([25000,50000,75000,100000,125000,150000,175000,200000])
g.set(xlabel='North America', ylabel='Salary')
g.legend(title='Organization Size',loc='upper right')

# %%
x = org_df[org_df['Continent']=='Europe']['Region']
plt.figure(figsize = (7, 5))
g=sns.barplot(x=x,y='ConvertedComp',data=org_df,ci=None,hue='Org_size')
g.yaxis.set_ticks([25000,50000,75000,100000,125000,150000,175000,200000])
g.set(xlabel='Europe', ylabel='Salary')
g.legend(title='Organization Size',loc='upper right')

# %%
x = org_df[org_df['Continent']=='South America']['Region']
plt.figure(figsize = (7, 5))
g=sns.barplot(x=x,y='ConvertedComp',data=org_df,ci=None,hue='Org_size')
g.yaxis.set_ticks([25000,50000,75000,100000,125000,150000,175000,200000])
g.set(xlabel='South America', ylabel='Salary')
g.legend(title='Organization Size',loc='upper right')

# %% [markdown]
# ###### The charts indicate that established companies pay more on average

# %% [markdown]
# # Reference
#
# https://github.com/jjrunner/stackoverflow/blob/master/HowToBreakIntoTheField.ipynb
